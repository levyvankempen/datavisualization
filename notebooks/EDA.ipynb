# %%
import pandas as pd

# %%
player_defense = pd.read_csv("../data/player_defense" + ".csv")
player_gca = pd.read_csv("../data/player_gca" + ".csv")
player_keepers = pd.read_csv("../data/player_keepers" + ".csv")
player_keepersadv = pd.read_csv("../data/player_keepersadv" + ".csv")
player_misc = pd.read_csv("../data/player_misc" + ".csv")
player_passing = pd.read_csv("../data/player_passing" + ".csv")
player_passing_types = pd.read_csv("../data/player_passing_types" + ".csv")
player_playingtime = pd.read_csv("../data/player_playingtime" + ".csv")
player_possession = pd.read_csv("../data/player_possession" + ".csv")
player_shooting = pd.read_csv("../data/player_shooting" + ".csv")
player_stats = pd.read_csv("../data/player_stats" + ".csv")

# %%
player_shooting.loc[player_shooting['team'] == 'Argentina']
# Out:
#                   player position       team     age  birth_year  minutes_90s  \
# 19   Alexis Mac Allister       MF  Argentina  23-359        1998          6.1
# 92       Cristian Romero       DF  Argentina  24-235        1998          6.1
# 132    Emiliano Martínez       GK  Argentina  30-107        1992          7.7
# 135       Enzo Fernández       MF  Argentina  21-335        2001          6.3
# 157      Gonzalo Montiel       DF  Argentina  25-351        1997          1.3
# 233       Julián Álvarez       FW  Argentina  22-321        2000          5.2
# 268     Lautaro Martínez       FW  Argentina  25-118        1997          2.7
# 271      Leandro Paredes       MF  Argentina  28-172        1994          2.5
# 277         Lionel Messi       FW  Argentina  35-177        1987          7.7
# 278    Lisandro Martínez       DF  Argentina  24-334        1998          3.4
# 290         Marcos Acuña       DF  Argentina  31-051        1991          4.1
# ...

# %%
player_gca.loc[player_gca['team'] == 'Argentina']
# Out:
#                   player position       team     age  birth_year  minutes_90s  \
# 19   Alexis Mac Allister       MF  Argentina  23-359        1998          6.1
# 92       Cristian Romero       DF  Argentina  24-235        1998          6.1
# 132    Emiliano Martínez       GK  Argentina  30-107        1992          7.7
# 135       Enzo Fernández       MF  Argentina  21-335        2001          6.3
# 157      Gonzalo Montiel       DF  Argentina  25-351        1997          1.3
# 233       Julián Álvarez       FW  Argentina  22-321        2000          5.2
# 268     Lautaro Martínez       FW  Argentina  25-118        1997          2.7
# 271      Leandro Paredes       MF  Argentina  28-172        1994          2.5
# 277         Lionel Messi       FW  Argentina  35-177        1987          7.7
# 278    Lisandro Martínez       DF  Argentina  24-334        1998          3.4
# 290         Marcos Acuña       DF  Argentina  31-051        1991          4.1
# ...

# %%
player_misc
# Out:
#                     player position        team     age  birth_year  \
# 0               Aaron Mooy       MF   Australia  32-094        1990
# 1             Aaron Ramsey       MF       Wales  31-357        1990
# 2        Abdelhamid Sabiri       MF     Morocco  26-020        1996
# 3        Abdelkarim Hassan       DF       Qatar  29-112        1993
# 4    Abdessamad Ezzalzouli       FW     Morocco  21-001        2001
# ..                     ...      ...         ...     ...         ...
# 480         Ángel Di María       MF   Argentina  34-307        1988
# 481        Ángelo Preciado       DF     Ecuador  24-303        1998
# 482           Éder Militão       DF      Brazil  24-334        1998
# 483           Óscar Duarte       DF  Costa Rica  33-198        1989
# 484         İlkay Gündoğan       MF     Germany  32-055        1990
#
#      minutes_90s  cards_yellow  cards_red  cards_yellow_red  fouls  ...  \
# 0            4.0             1          0                 0      4  ...
# ...

# %%
player_defense
# Out:
#                     player position        team     age  birth_year  \
# 0               Aaron Mooy       MF   Australia  32-094        1990
# 1             Aaron Ramsey       MF       Wales  31-357        1990
# 2        Abdelhamid Sabiri       MF     Morocco  26-020        1996
# 3        Abdelkarim Hassan       DF       Qatar  29-112        1993
# 4    Abdessamad Ezzalzouli       FW     Morocco  21-001        2001
# ..                     ...      ...         ...     ...         ...
# 480         Ángel Di María       MF   Argentina  34-307        1988
# 481        Ángelo Preciado       DF     Ecuador  24-303        1998
# 482           Éder Militão       DF      Brazil  24-334        1998
# 483           Óscar Duarte       DF  Costa Rica  33-198        1989
# 484         İlkay Gündoğan       MF     Germany  32-055        1990
#
#      minutes_90s  tackles  tackles_won  tackles_def_3rd  tackles_mid_3rd  ...  \
# ...

# %%
player_possession.loc[player_possession['team'] == 'Argentina']
# Out:
#                   player position       team     age  birth_year  minutes_90s  \
# 19   Alexis Mac Allister       MF  Argentina  23-359        1998          6.1
# 92       Cristian Romero       DF  Argentina  24-235        1998          6.1
# 132    Emiliano Martínez       GK  Argentina  30-107        1992          7.7
# 135       Enzo Fernández       MF  Argentina  21-335        2001          6.3
# 157      Gonzalo Montiel       DF  Argentina  25-351        1997          1.3
# 233       Julián Álvarez       FW  Argentina  22-321        2000          5.2
# 268     Lautaro Martínez       FW  Argentina  25-118        1997          2.7
# 271      Leandro Paredes       MF  Argentina  28-172        1994          2.5
# 277         Lionel Messi       FW  Argentina  35-177        1987          7.7
# 278    Lisandro Martínez       DF  Argentina  24-334        1998          3.4
# 290         Marcos Acuña       DF  Argentina  31-051        1991          4.1
# ...

# %%
player_stats
# Out:
#                     player position        team     age             club  \
# 0               Aaron Mooy       MF   Australia  32-094           Celtic
# 1             Aaron Ramsey       MF       Wales  31-357             Nice
# 2        Abdelhamid Sabiri       MF     Morocco  26-020        Sampdoria
# 3        Abdelkarim Hassan       DF       Qatar  29-112       Al Sadd SC
# 4    Abdessamad Ezzalzouli       FW     Morocco  21-001          Osasuna
# ..                     ...      ...         ...     ...              ...
# 480         Ángel Di María       MF   Argentina  34-307         Juventus
# 481        Ángelo Preciado       DF     Ecuador  24-303             Genk
# 482           Éder Militão       DF      Brazil  24-334      Real Madrid
# 483           Óscar Duarte       DF  Costa Rica  33-198         Al-Wehda
# 484         İlkay Gündoğan       MF     Germany  32-055  Manchester City
#
#      birth_year  games  games_starts  minutes  minutes_90s  ...  \
# ...

# %%
player_shooting
# Out:
#                     player position        team     age  birth_year  \
# 0               Aaron Mooy       MF   Australia  32-094        1990
# 1             Aaron Ramsey       MF       Wales  31-357        1990
# 2        Abdelhamid Sabiri       MF     Morocco  26-020        1996
# 3        Abdelkarim Hassan       DF       Qatar  29-112        1993
# 4    Abdessamad Ezzalzouli       FW     Morocco  21-001        2001
# ..                     ...      ...         ...     ...         ...
# 480         Ángel Di María       MF   Argentina  34-307        1988
# 481        Ángelo Preciado       DF     Ecuador  24-303        1998
# 482           Éder Militão       DF      Brazil  24-334        1998
# 483           Óscar Duarte       DF  Costa Rica  33-198        1989
# 484         İlkay Gündoğan       MF     Germany  32-055        1990
#
#      minutes_90s  goals  shots  shots_on_target  shots_on_target_pct  ...  \
# 0            4.0      0      1                0                  0.0  ...
# ...

# %%
player_shooting_stats_combined = player_shooting.join(player_stats['club'])

# %%
player_shooting_stats_combined.loc[player_shooting_stats_combined['club'] == 'Manchester City']
# Out:
#               player position         team     age  birth_year  minutes_90s  \
# 55   Aymeric Laporte       DF        Spain  28-205        1994          3.3
# 65    Bernardo Silva       MF     Portugal  28-130        1994          4.0
# 124          Ederson       GK       Brazil  29-123        1993          1.0
# 195    Jack Grealish       FW      England  27-099        1995          1.0
# 213      John Stones       DF      England  28-204        1994          4.8
# 227     João Cancelo       DF     Portugal  28-205        1994          3.4
# 233   Julián Álvarez       FW    Argentina  22-321        2000          5.2
# 249  Kevin De Bruyne       FW      Belgium  31-173        1991          3.0
# 266      Kyle Walker       DF      England  32-204        1990          2.6
# 286    Manuel Akanji       DF  Switzerland  27-152        1995          4.0
# 337       Nathan Aké       DF  Netherlands  27-303        1995          5.3
# ...
